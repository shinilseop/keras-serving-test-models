# %% [markdown]
# # English-to-Spanish translation with a sequence-to-sequence Transformer
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2021/05/26<br>
# **Last modified:** 2021/05/26<br>
# **Description:** Implementing a sequence-to-sequene Transformer and training it on a machine translation task.

# %% [markdown]
# ## Introduction
#
# In this example, we'll build a sequence-to-sequence Transformer model, which
# we'll train on an English-to-Spanish machine translation task.
#
# You'll learn how to:
#
# - Vectorize text using the Keras `TextVectorization` layer.
# - Implement a `TransformerEncoder` layer, a `TransformerDecoder` layer,
# and a `PositionalEmbedding` layer.
# - Prepare data for training a sequence-to-sequence model.
# - Use the trained model to generate translations of never-seen-before
# input sentences (sequence-to-sequence inference).
#
# The code featured here is adapted from the book
# [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition)
# (chapter 11: Deep learning for text).
# The present example is fairly barebones, so for detailed explanations of
# how each building block works, as well as the theory behind Transformers,
# I recommend reading the book.

# %% [markdown]
# ## Setup

# %%
import pathlib
import random
import string
import re
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

# %% [markdown]
# ## Downloading the data
#
# We'll be working with an English-to-Spanish translation dataset
# provided by [Anki](https://www.manythings.org/anki/). Let's download it:

# %%
text_file = keras.utils.get_file(
    fname="spa-eng.zip",
    origin="http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip",
    extract=True,
)
text_file = pathlib.Path(text_file).parent / "spa-eng" / "spa.txt"
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip
# 2646016/2638744 [==============================] - 0s 0us/step
# 2654208/2638744 [==============================] - 0s 0us/step

# %% [markdown]
# ## Parsing the data
#
# Each line contains an English sentence and its corresponding Spanish sentence.
# The English sentence is the *source sequence* and Spanish one is the *target sequence*.
# We prepend the token `"[start]"` and we append the token `"[end]"` to the Spanish sentence.

# %%
with open(text_file) as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    eng, spa = line.split("\t")
    spa = "[start] " + spa + " [end]"
    text_pairs.append((eng, spa))

# %% [markdown]
# Here's what our sentence pairs look like:

# %%
for _ in range(5):
    print(random.choice(text_pairs))
# Out:
# ('How tall you are!', '[start] ¡Qué alto eres! [end]')
# ("I didn't know how to respond.", '[start] No sabía cómo responder. [end]')
# ('He had his share of luck.', '[start] Tuvo su cuota de suerte. [end]')
# ('These problems will be solved in the near future.', '[start] Estos problemas se resolverán en un futuro próximo. [end]')
# ('Tom wants a detailed explanation.', '[start] Tom quiere una explicación detallada. [end]')

# %% [markdown]
# Now, let's split the sentence pairs into a training set, a validation set,
# and a test set.

# %%
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples : num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples :]

print(f"{len(text_pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(val_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 118964 total pairs
# 83276 training pairs
# 17844 validation pairs
# 17844 test pairs

# %% [markdown]
# ## Vectorizing the text data
#
# We'll use two instances of the `TextVectorization` layer to vectorize the text
# data (one for English and one for Spanish),
# that is to say, to turn the original strings into integer sequences
# where each integer represents the index of a word in a vocabulary.
#
# The English layer will use the default string standardization (strip punctuation characters)
# and splitting scheme (split on whitespace), while
# the Spanish layer will use a custom standardization, where we add the character
# `"¿"` to the set of punctuation characters to be stripped.
#
# Note: in a production-grade machine translation model, I would not recommend
# stripping the punctuation characters in either language. Instead, I would recommend turning
# each punctuation character into its own token,
# which you could achieve by providing a custom `split` function to the `TextVectorization` layer.

# %%
strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

vocab_size = 15000
sequence_length = 20
batch_size = 64


def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


eng_vectorization = TextVectorization(
    max_tokens=vocab_size, output_mode="int", output_sequence_length=sequence_length,
)
spa_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_eng_texts = [pair[0] for pair in train_pairs]
train_spa_texts = [pair[1] for pair in train_pairs]
eng_vectorization.adapt(train_eng_texts)
spa_vectorization.adapt(train_spa_texts)

# %% [markdown]
# Next, we'll format our datasets.
#
# At each training step, the model will seek to predict target words N+1 (and beyond)
# using the source sentence and the target words 0 to N.
#
# As such, the training dataset will yield a tuple `(inputs, targets)`, where:
#
# - `inputs` is a dictionary with the keys `encoder_inputs` and `decoder_inputs`.
# `encoder_inputs` is the vectorized source sentence and `encoder_inputs` is the target sentence "so far",
# that is to say, the words 0 to N used to predict word N+1 (and beyond) in the target sentence.
# - `target` is the target sentence offset by one step:
# it provides the next words in the target sentence -- what the model will try to predict.

# %%
def format_dataset(eng, spa):
    eng = eng_vectorization(eng)
    spa = spa_vectorization(spa)
    return ({"encoder_inputs": eng, "decoder_inputs": spa[:, :-1],}, spa[:, 1:])


def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf.data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.shuffle(2048).prefetch(16).cache()


train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %% [markdown]
# Let's take a quick look at the sequence shapes
# (we have batches of 64 pairs, and all sequences are 20 steps long):

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f"targets.shape: {targets.shape}")
# Out:
# inputs["encoder_inputs"].shape: (64, 20)
# inputs["decoder_inputs"].shape: (64, 20)
# targets.shape: (64, 20)

# %% [markdown]
# ## Building the model
#
# Our sequence-to-sequence Transformer consists of a `TransformerEncoder`
# and a `TransformerDecoder` chained together. To make the model aware of word order,
# we also use a `PositionalEmbedding` layer.
#
# The source sequence will be pass to the `TransformerEncoder`,
# which will produce a new representation of it.
# This new representation will then be passed
# to the `TransformerDecoder`, together with the target sequence so far (target words 0 to N).
# The `TransformerDecoder` will then seek to predict the next words in the target sequence (N+1 and beyond).
#
# A key detail that makes this possible is causal masking
# (see method `get_causal_attention_mask()` on the `TransformerDecoder`).
# The `TransformerDecoder` sees the entire sequences at once, and thus we must make
# sure that it only uses information from target tokens 0 to N when predicting token N+1
# (otherwise, it could use information from the future, which would
# result in a model that cannot be used at inference time).

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super(TransformerEncoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, mask=None):
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, tf.newaxis, :], dtype="int32")
        attention_output = self.attention(
            query=inputs, value=inputs, key=inputs, attention_mask=padding_mask
        )
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)
    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "dense_dim": self.dense_dim,
            "num_heads": self.num_heads,
        })
        return config


class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super(PositionalEmbedding, self).__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)
    def get_config(self):
        config = super().get_config()
        config.update({
            "sequence_length": self.sequence_length,
            "vocab_size": self.vocab_size,
            "embed_dim": self.embed_dim,
        })
        return config


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super(TransformerDecoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(latent_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, attention_mask=causal_mask
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)
    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "latent_dim": self.latent_dim,
            "num_heads": self.num_heads,
        })
        return config

# %% [markdown]
# Next, we assemble the end-to-end model.

# %%
embed_dim = 256
latent_dim = 2048
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
encoder = keras.Model(encoder_inputs, encoder_outputs)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="decoder_state_inputs")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
decoder = keras.Model([decoder_inputs, encoded_seq_inputs], decoder_outputs)

decoder_outputs = decoder([decoder_inputs, encoder_outputs])
transformer = keras.Model(
    [encoder_inputs, decoder_inputs], decoder_outputs, name="transformer"
)

# %% [markdown]
# ## Training our model
#
# We'll use accuracy as a quick way to monitor training progress on the validation data.
# Note that machine translation typically uses BLEU scores as well as other metrics, rather than accuracy.
#
# Here we only train for 1 epoch, but to get the model to actually converge
# you should train for at least 30 epochs.

# %%
epochs = 50  # This should be at least 30 for convergence
filename = "English-to-Spanish_translater.h5"
callback_list = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=1),
             keras.callbacks.ModelCheckpoint(filename, monitor='accuracy', verbose=1, save_best_only=True, save_weights_only=True, mode='auto')]

# %%
transformer.compile(
    "rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
transformer.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  positional_embedding (Position  (None, None, 256)   3845120     ['encoder_inputs[0][0]']
#  alEmbedding)
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  transformer_encoder (Transform  (None, None, 256)   3155456     ['positional_embedding[0][0]']
#  erEncoder)
#
#  model_1 (Functional)           (None, None, 15000)  12959640    ['decoder_inputs[0][0]',
#                                                                   'transformer_encoder[0][0]']
#
# ==================================================================================================
# Total params: 19,960,216
# Trainable params: 19,960,216
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from datetime import datetime

print("train start  :",datetime.now())
transformer.fit(train_ds, epochs=epochs, validation_data=val_ds, callbacks=callback_list)
print("train finish :",datetime.now())
# Out:
# train start  : 2022-09-19 08:09:58.290998
# Epoch 1/50
# 1302/1302 [==============================] - ETA: 0s - loss: 1.6980 - accuracy: 0.4096
# Epoch 1: accuracy improved from -inf to 0.40957, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 102s 72ms/step - loss: 1.6980 - accuracy: 0.4096 - val_loss: 1.3548 - val_accuracy: 0.5015
# Epoch 2/50
# 1302/1302 [==============================] - ETA: 0s - loss: 1.3573 - accuracy: 0.5256
# Epoch 2: accuracy improved from 0.40957 to 0.52561, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 93s 71ms/step - loss: 1.3573 - accuracy: 0.5256 - val_loss: 1.1768 - val_accuracy: 0.5646
# Epoch 3/50
# 1302/1302 [==============================] - ETA: 0s - loss: 1.1985 - accuracy: 0.5763
# Epoch 3: accuracy improved from 0.52561 to 0.57634, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 1.1985 - accuracy: 0.5763 - val_loss: 1.0957 - val_accuracy: 0.5976
# Epoch 4/50
# 1302/1302 [==============================] - ETA: 0s - loss: 1.1045 - accuracy: 0.6106
# Epoch 4: accuracy improved from 0.57634 to 0.61064, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 1.1045 - accuracy: 0.6106 - val_loss: 1.0505 - val_accuracy: 0.6191
# Epoch 5/50
# 1302/1302 [==============================] - ETA: 0s - loss: 1.0531 - accuracy: 0.6338
# Epoch 5: accuracy improved from 0.61064 to 0.63383, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 91s 70ms/step - loss: 1.0531 - accuracy: 0.6338 - val_loss: 1.0236 - val_accuracy: 0.6304
# Epoch 6/50
# 1302/1302 [==============================] - ETA: 0s - loss: 1.0215 - accuracy: 0.6498
# Epoch 6: accuracy improved from 0.63383 to 0.64982, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 1.0215 - accuracy: 0.6498 - val_loss: 1.0064 - val_accuracy: 0.6404
# Epoch 7/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.9974 - accuracy: 0.6632
# Epoch 7: accuracy improved from 0.64982 to 0.66324, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 0.9974 - accuracy: 0.6632 - val_loss: 1.0094 - val_accuracy: 0.6426
# Epoch 8/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.9779 - accuracy: 0.6741
# Epoch 8: accuracy improved from 0.66324 to 0.67411, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 91s 70ms/step - loss: 0.9779 - accuracy: 0.6741 - val_loss: 0.9989 - val_accuracy: 0.6492
# Epoch 9/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.9611 - accuracy: 0.6830
# Epoch 9: accuracy improved from 0.67411 to 0.68303, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 0.9611 - accuracy: 0.6830 - val_loss: 0.9968 - val_accuracy: 0.6531
# Epoch 10/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.9468 - accuracy: 0.6912
# Epoch 10: accuracy improved from 0.68303 to 0.69122, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 70ms/step - loss: 0.9468 - accuracy: 0.6912 - val_loss: 0.9999 - val_accuracy: 0.6538
# Epoch 11/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.9323 - accuracy: 0.6981
# Epoch 11: accuracy improved from 0.69122 to 0.69809, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 91s 70ms/step - loss: 0.9323 - accuracy: 0.6981 - val_loss: 1.0046 - val_accuracy: 0.6553
# Epoch 12/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.9200 - accuracy: 0.7044
# Epoch 12: accuracy improved from 0.69809 to 0.70437, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 70ms/step - loss: 0.9200 - accuracy: 0.7044 - val_loss: 1.0082 - val_accuracy: 0.6526
# Epoch 13/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.9073 - accuracy: 0.7108
# Epoch 13: accuracy improved from 0.70437 to 0.71083, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 0.9073 - accuracy: 0.7108 - val_loss: 1.0085 - val_accuracy: 0.6570
# Epoch 14/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.8954 - accuracy: 0.7160
# Epoch 14: accuracy improved from 0.71083 to 0.71598, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 0.8954 - accuracy: 0.7160 - val_loss: 1.0030 - val_accuracy: 0.6610
# Epoch 15/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.8841 - accuracy: 0.7205
# Epoch 15: accuracy improved from 0.71598 to 0.72052, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 0.8841 - accuracy: 0.7205 - val_loss: 1.0126 - val_accuracy: 0.6574
# Epoch 16/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.8739 - accuracy: 0.7247
# Epoch 16: accuracy improved from 0.72052 to 0.72472, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 70ms/step - loss: 0.8739 - accuracy: 0.7247 - val_loss: 1.0111 - val_accuracy: 0.6622
# Epoch 17/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.8633 - accuracy: 0.7294
# Epoch 17: accuracy improved from 0.72472 to 0.72939, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 0.8633 - accuracy: 0.7294 - val_loss: 1.0219 - val_accuracy: 0.6571
# Epoch 18/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.8536 - accuracy: 0.7334
# Epoch 18: accuracy improved from 0.72939 to 0.73345, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 93s 71ms/step - loss: 0.8536 - accuracy: 0.7334 - val_loss: 1.0188 - val_accuracy: 0.6611
# Epoch 19/50
# 1302/1302 [==============================] - ETA: 0s - loss: 0.8441 - accuracy: 0.7370
# Epoch 19: accuracy improved from 0.73345 to 0.73704, saving model to English-to-Spanish_translater.h5
# 1302/1302 [==============================] - 92s 71ms/step - loss: 0.8441 - accuracy: 0.7370 - val_loss: 1.0234 - val_accuracy: 0.6613
# Epoch 19: early stopping
# train finish : 2022-09-19 08:48:19.267153

# %%
# epochs = 1  # This should be at least 30 for convergence

# transformer.summary()
# transfoq  rmer.compile(
#     "rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
# )
# transformer.fit(train_ds, epochs=epochs, validation_data=val_ds)

# %% [markdown]
# ## Decoding test sentences
#
# Finally, let's demonstrate how to translate brand new English sentences.
# We simply feed into the model the vectorized English sentence
# as well as the target token `"[start]"`, then we repeatedly generated the next token, until
# we hit the token `"[end]"`.

# %%
spa_vocab = spa_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20


def decode_sequence(input_sentence):
    tokenized_input_sentence = eng_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = spa_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence


test_eng_texts = [pair[0] for pair in test_pairs]


for _ in range(1000):
    input_sentence = random.choice(test_eng_texts)
    translated = decode_sequence(input_sentence)
    print(input_sentence," >>> ",translated)
# Out:
# Can you read French?  >>>  [start] sabes leer francés [end]
# Forget about that right now.  >>>  [start] ahora [UNK] de eso [end]
# You must have a lot of patience to learn foreign languages.  >>>  [start] debes tener mucha paciencia por la [UNK] [end]
# Is anybody hurt?  >>>  [start] está alguien herido [end]
# I agree with you completely.  >>>  [start] estoy de acuerdo con todo el sentido [end]
# What time should I go to the airport?  >>>  [start] a qué hora tengo que ir al aeropuerto [end]
# You're embarrassing me.  >>>  [start] me estás [UNK] [end]
# I really got depressed.  >>>  [start] me [UNK] [end]
# Tom intends to become a journalist.  >>>  [start] tom [UNK] ser un un un un un un un un un un un un un un un un un
# She writes to me once a month.  >>>  [start] ella me escribe una vez en mes [end]
# The company suffered big losses.  >>>  [start] la compañía compañía [UNK] grande [end]
# Women are beautiful.  >>>  [start] las mujeres son linda [end]
# I don't know why it didn't work.  >>>  [start] no sé por qué no lo no lo [UNK] [end]
# The artist who illustrated this book is very good.  >>>  [start] el se de las tenido de nuevo que este libro está muy bien [end]
# Do you want to wait in the car?  >>>  [start] quieres esperar [end]
# One of us is wrong.  >>>  [start] uno de nosotros es malo [end]
# I remember having seen him somewhere before.  >>>  [start] me acuerdo de visto en algún lugar antes [end]
# I'm not as talkative as you.  >>>  [start] no soy tan [UNK] como tú [end]
# Tom certainly seemed to enjoy the party last Friday night.  >>>  [start] tom parecía [UNK] la fiesta de la habitación el viernes por la noche [end]
# He did what he had been told.  >>>  [start] hizo lo que se había dicho [end]
# If you don't like it, don't eat it.  >>>  [start] si no te [UNK] eso no lo hace [end]
# This building belongs to us.  >>>  [start] este edificio les gustan [end]
# Was Tom ever married?  >>>  [start] tom ha casado una vez [end]
# What do you mean?  >>>  [start] qué quieres decir [end]
# It's completely natural.  >>>  [start] es completamente [end]
# One out of three people in this city owns a car.  >>>  [start] una tres tres personas en esta ciudad de la ciudad un auto [end]
# Some Italian fashion designers are saying that white bathing suits will catch on this year.  >>>  [start] algunos de [UNK] de [UNK] que alguien se [UNK] se [UNK] en este año [end]
# That's broken.  >>>  [start] eso está [UNK] [end]
# Tom is patient.  >>>  [start] tom tiene paciencia [end]
# What shall I begin with?  >>>  [start] qué voy a pasar con en el que estoy [end]

# %% [markdown]
# After 30 epochs, we get results such as:
#
# > She handed him the money.
# > [start] ella le pasó el dinero [end]
#
# > Tom has never heard Mary sing.
# > [start] tom nunca ha oído cantar a mary [end]
#
# > Perhaps she will come tomorrow.
# > [start] tal vez ella vendrá mañana [end]
#
# > I love to write.
# > [start] me encanta escribir [end]
#
# > His French is improving little by little.
# > [start] su francés va a [UNK] sólo un poco [end]
#
# > My hotel told me to call you.
# > [start] mi hotel me dijo que te [UNK] [end]

# %%
from datetime import datetime

print("predict start : ",datetime.now())
for _ in range(1000):
    input_sentence = random.choice(test_eng_texts)
    translated = decode_sequence(input_sentence)
    print(_,"\t:",input_sentence," >>> ",translated)
print("predict finish : ",datetime.now())
# Out:
# predict start :  2022-09-19 08:57:21.150702
# 0 	: I'm breaking up with my girlfriend tonight.  >>>  [start] estoy [UNK] con mi novia [end]
# 1 	: She could not understand the whole story.  >>>  [start] no pudo entender toda la historia [end]
# 2 	: Tom needs more time.  >>>  [start] tom necesita tiempo más tiempo [end]
# 3 	: She looked as if she had been sick for a long time.  >>>  [start] ella miró como si había estado enfermo en mucho tiempo [end]
# 4 	: This work is by no means easy.  >>>  [start] este trabajo no es de la [UNK] [end]
# 5 	: Tom made a list of things he wanted to do before he died.  >>>  [start] tom hizo una lista de las cosas que quería hacer antes de que se había muerto [end]
# 6 	: He won the lottery.  >>>  [start] Él se ha [UNK] la cabeza [end]
# 7 	: You have something of mine.  >>>  [start] tienes algo de mío [end]
# 8 	: This is a big project.  >>>  [start] este es un gran plan [end]
# 9 	: He had lost all political power.  >>>  [start] Él había perdido todo en la se [UNK] [end]
# 10 	: I'm not proud of this.  >>>  [start] no estoy orgulloso de esto [end]
# 11 	: Glaciers around the world are melting.  >>>  [start] [UNK] por sobre el mundo está [UNK] [end]
# 12 	: I'm still up.  >>>  [start] todavía estoy en la [UNK] [end]
# 13 	: She visited him on October 20th.  >>>  [start] ella lo ha [UNK] de [UNK] el de ciudadano de [UNK] [end]
# 14 	: The accident has caused many deaths.  >>>  [start] el accidente tiene muchos [UNK] [end]
# 15 	: An artist uses many tubes of paint to make a large painting.  >>>  [start] un se lleva muchos [UNK] de la televisión una linda para hacer [end]
# 16 	: Tom knows that what he did was wrong.  >>>  [start] tom sabe lo que hizo fue malo [end]
# 17 	: This heater burns gas.  >>>  [start] este de de de [end]
# 18 	: Do you know what he said?  >>>  [start] sabes lo que dijo [end]
# 19 	: Why are you so tired today?  >>>  [start] por qué estás tan cansado hoy [end]
# 20 	: Can I speak to the manager?  >>>  [start] puedo hablar con el [UNK] [end]
# 21 	: Thanks for listening.  >>>  [start] gracias por entender [end]
# 22 	: Have you read this report?  >>>  [start] has leído este [end]
# 23 	: Mary is Tom's stepdaughter.  >>>  [start] mary es la [UNK] de tom [end]
# 24 	: I rang the bell six times.  >>>  [start] me he [UNK] la primera vez a las seis [end]
# 25 	: Leave everything.  >>>  [start] [UNK] todo [end]
# 26 	: There shouldn't be any commas in this sentence.  >>>  [start] no debería haber nada de [UNK] en esta línea [end]
# 27 	: This is the very dictionary that I have been looking for.  >>>  [start] este es el diccionario muy que he estado esperando [end]
# 28 	: He likes this book.  >>>  [start] le gusta este libro [end]
# 29 	: I always drink a glass of milk before going to bed.  >>>  [start] siempre de beber una leche antes de ir a la cama [end]
# 30 	: They always talk about the same things.  >>>  [start] ellos siempre hablan de las cosas [end]
# 31 	: It was raining heavily in Osaka.  >>>  [start] estuvo oscuro en alemania [end]
# 32 	: For me, time is not money.  >>>  [start] para mí el tiempo es un dinero [end]
# 33 	: Are you sure you haven't forgotten anything?  >>>  [start] estás seguro de que no te ha ido de la has ido de repente [end]
# 34 	: Tom doesn't know anything about Mary.  >>>  [start] tom no sabe nada sobre mary [end]
# 35 	: What's your favorite board game?  >>>  [start] cuál es tu juego de juego favorito [end]
# 36 	: The official start is on Saturday.  >>>  [start] las de [UNK] por las domingos [end]
# 37 	: I want your opinion, too.  >>>  [start] quiero tu opinión [end]
# 38 	: Where are all the others?  >>>  [start] dónde están todos los otros [end]
# 39 	: Is there any beer left?  >>>  [start] hay alguna cerveza [end]
# 40 	: I can't live that kind of life.  >>>  [start] no puedo vivir esa clase de vida [end]
# 41 	: I usually go to bed at nine.  >>>  [start] a pescar los domingos me a las nueve [end]
# 42 	: Tom wanted to stay at home.  >>>  [start] tom quería estar en la casa [end]
# 43 	: You're very smart.  >>>  [start] sos muy listo [end]
# 44 	: Tom leaned on the counter.  >>>  [start] tom se cayó en el de de en el de [UNK] [end]
# 45 	: I went to the park to play tennis.  >>>  [start] fui al parque a jugar al tenis [end]
# 46 	: I'm happy to see you here.  >>>  [start] estoy contento de verte aquí [end]
# 47 	: She left for Paris.  >>>  [start] ella dejó a parís [end]
# 48 	: This can't be a coincidence.  >>>  [start] esto no puede ser de una puedes ser [UNK] [end]
# 49 	: It would be nice if you had a wedge of lime I could squeeze into my icewater.  >>>  [start] sería bueno hacer una si hubiera [UNK] una [UNK] de la vida en mi lo que se [UNK] a la
# 50 	: I don't have to clean my room.  >>>  [start] no tengo que llamar mi habitación [end]
# 51 	: The weather was very good.  >>>  [start] el día era muy buena [end]
# 52 	: Don't get any ideas.  >>>  [start] no olvides hacer ideas [end]
# 53 	: The trial will continue Monday.  >>>  [start] el de [UNK] se [UNK] el lunes [end]
# 54 	: Who could have spread that news?  >>>  [start] cómo pudo haber recibido esa noticia [end]
# 55 	: She saw him at the station.  >>>  [start] la vio en la estación [end]
# 56 	: Wash your hands before you eat.  >>>  [start] [UNK] las manos antes de comer [end]
# 57 	: I just moved to Boston.  >>>  [start] me he [UNK] a boston [end]
# 58 	: He dropped in at my house last night.  >>>  [start] la última carta en mi casa anoche [end]
# 59 	: Let me know when you get that report back from Tom.  >>>  [start] [UNK] que cuando te [UNK] el de tom [end]
# 60 	: I want to buy a dozen bananas.  >>>  [start] quiero comprar una [UNK] [end]
# 61 	: My mother gets up the earliest every morning.  >>>  [start] mi madre se lleva la mañana en la mañana [end]
# 62 	: Tom gave Mary the keys.  >>>  [start] tom dio las llaves a mary [end]
# 63 	: Tom didn't know anything about Mary's past.  >>>  [start] tom no sabía nada sobre el pasado de mary [end]
# 64 	: I couldn't do that to Tom.  >>>  [start] no podía hacer eso a tom [end]
# 65 	: I stayed.  >>>  [start] me quedé [end]
# 66 	: That water pipe leaks.  >>>  [start] ese agua tiene una [UNK] [end]
# 67 	: I hope you die.  >>>  [start] espero que [UNK] [end]
# 68 	: I really want to figure this out.  >>>  [start] en realidad quiero de todas eso [end]
# 69 	: Check everyone.  >>>  [start] [UNK] a todos [end]
# 70 	: Don't touch me!  >>>  [start] no me no lo [UNK] [end]
# 71 	: I want to get even with him for the insult.  >>>  [start] quiero ir hacia punto de [UNK] la [end]
# 72 	: Have you ever seen such a beautiful sunset?  >>>  [start] alguna vez has visto a una semana tan grande [end]
# 73 	: I have a slight headache now.  >>>  [start] ahora tengo un poco de dolor de cabeza [end]
# 74 	: We're sophomores.  >>>  [start] somos de tomás de medio tiempo [end]
# 75 	: No one will care.  >>>  [start] a nadie le [UNK] [end]
# 76 	: You're the best thing that ever happened to me.  >>>  [start] sos el mejor que me ha pasado en mí [end]
# 77 	: Squirrels move quickly.  >>>  [start] los se [UNK] a menudo el [UNK] [end]
# 78 	: He rolled over in his sleep.  >>>  [start] Él se puso por su sueño [end]
# 79 	: I want to be a magician.  >>>  [start] quiero ser un [UNK] [end]
# 80 	: Tom doesn't feel like cooking.  >>>  [start] tom no tiene ganas de cocinar [end]
# 81 	: Can I ask you something?  >>>  [start] te puedo hacer algo [end]
# 82 	: Children love to dig in the sand.  >>>  [start] a los niños les [UNK] en la tormenta [end]
# 83 	: She loves him.  >>>  [start] ella le ama [end]
# 84 	: He is afraid of his grandfather.  >>>  [start] Él le tiene miedo a su abuelo [end]
# 85 	: You are very fortunate that you have such friends.  >>>  [start] estás en este de [UNK] tienes amigos [end]
# 86 	: Pardon me, but that is my racket.  >>>  [start] [UNK] pero ese es mi [end]
# 87 	: I am divorced.  >>>  [start] estoy [UNK] [end]
# 88 	: Who helps your mother?  >>>  [start] quién ayuda a tu madre [end]
# 89 	: He went to bed after supper.  >>>  [start] Él se fue a la cama después de la cena [end]
# 90 	: Rice is sold by the kilogram.  >>>  [start] el arroz se llama por las [UNK] [end]
# 91 	: What do you want to do first?  >>>  [start] qué quieres hacer yo yo mismo [end]
# 92 	: This coffee is so hot that I can't drink it.  >>>  [start] este café está muy tan caliente no puedo beber [end]
# 93 	: He stalled the engine three times.  >>>  [start] el [UNK] [UNK] los [UNK] tres veces [end]
# 94 	: Don't dwell too much upon the subject.  >>>  [start] no se [UNK] demasiado a lo [UNK] [end]
# 95 	: He has a long neck.  >>>  [start] tiene un largo camino el cuello [end]
# 96 	: A man who breaks his promises cannot be trusted.  >>>  [start] un hombre que [UNK] sus en la [UNK] no puede confiar en él [end]
# 97 	: I felt sorry for her when I heard her story.  >>>  [start] me lo siento por ella cuando la he oído de la historia [end]
# 98 	: Did Tom ask you out?  >>>  [start] tom te ha [UNK] [end]
# 99 	: I'm still here.  >>>  [start] todavía estoy aquí [end]
# 100 	: I am just going for a walk.  >>>  [start] voy a ir a un paseo [end]
# 101 	: I can't stand noisy children.  >>>  [start] no puedo terminar hijos como niños [end]
# 102 	: Tom said that he wanted to forget Mary.  >>>  [start] tom dijo que quería de que él quería de mary [end]
# 103 	: Let's sit down on that bench.  >>>  [start] [UNK] en el banco [end]
# 104 	: Just do what I tell you.  >>>  [start] solo ¡qué lo que te digas [end]
# 105 	: You ought to be on time if you start now.  >>>  [start] deberías estar en el momento si [UNK] ahora [end]
# 106 	: If I'd known what was about to happen, I wouldn't have done that.  >>>  [start] si hubiera encontrado lo que estaba a punto de llegar eso [end]
# 107 	: She was married to a rich man.  >>>  [start] ella se casó con un hombre rico [end]
# 108 	: Neither defendant was found guilty.  >>>  [start] nadie [UNK] fue culpable [end]
# 109 	: He was the one who suggested it.  >>>  [start] Él fue el que la última a decir [end]
# 110 	: She knelt beside him.  >>>  [start] se te [UNK] al lado [end]
# 111 	: What are you babbling about?  >>>  [start] en qué estás [UNK] [end]
# 112 	: We had hardly started when it began to rain.  >>>  [start] en cuanto nos vimos [end]
# 113 	: You're talking nonsense.  >>>  [start] estás hablando de la [UNK] [end]
# 114 	: Tom sent Mary some flowers.  >>>  [start] tom le ha dicho a mary algunas flores [end]
# 115 	: Tom sharpened a pencil.  >>>  [start] tom [UNK] un lápiz [end]
# 116 	: I'm glad that you'll come.  >>>  [start] me alegro de que te [UNK] [end]
# 117 	: I can't eat anything today.  >>>  [start] hoy no puedo comer nada [end]
# 118 	: Just seeing it made me nervous.  >>>  [start] solo [UNK] me lo ha hecho nervioso [end]
# 119 	: Are you still sleepy?  >>>  [start] todavía tienes sueño [end]
# 120 	: Where is the boy?  >>>  [start] dónde está el niño [end]
# 121 	: Are you sisters?  >>>  [start] sos hermanas [end]
# 122 	: I thought you'd be glad to see Tom.  >>>  [start] pensé que te [UNK] a tom [end]
# 123 	: I get along with my younger brother.  >>>  [start] me [UNK] con mi hermano mayor [end]
# 124 	: I want to get even with him for the insult.  >>>  [start] quiero ir hacia punto de [UNK] la [end]
# 125 	: Tom used to do that.  >>>  [start] tom solía hacerlo [end]
# 126 	: I do remember doing that.  >>>  [start] me acuerdo hecho hacer eso [end]
# 127 	: He's a very hard worker.  >>>  [start] Él es un muy [UNK] [end]
# 128 	: This bomb can kill a lot of people.  >>>  [start] esta bomba puede matar a los personas [end]
# 129 	: Don't back up. There's a tree behind you.  >>>  [start] no se me [UNK] el árbol entre vos [end]
# 130 	: Willingness to take responsibility is a sign of maturity.  >>>  [start] [UNK] tomar la se [UNK] es una [UNK] de [UNK] [end]
# 131 	: The army abandoned the town to the enemy.  >>>  [start] el se ha [UNK] la ciudad al enemigo [end]
# 132 	: The boy ran away.  >>>  [start] el niño se cayó en cuanto [UNK] [end]
# 133 	: I'm not frightened of ghosts.  >>>  [start] no tengo miedo de los la [UNK] de los la verdad [end]
# 134 	: Who's your father?  >>>  [start] quién es tu padre [end]
# 135 	: Check everyone.  >>>  [start] [UNK] a todos [end]
# 136 	: He wants to get rid of his books.  >>>  [start] Él quiere [UNK] de los libros [end]
# 137 	: He cut a twig from the tree with his knife.  >>>  [start] Él [UNK] una [UNK] del árbol [end]
# 138 	: He goes to the office by car.  >>>  [start] Él va a la oficina en auto [end]
# 139 	: Your friends are late.  >>>  [start] tus amigos llegó tarde [end]
# 140 	: How you've grown!  >>>  [start] cómo te [UNK] [end]
# 141 	: Am I alone here?  >>>  [start] estoy sola aquí [end]
# 142 	: I've been to Boston three times.  >>>  [start] he estado en boston tres veces [end]
# 143 	: Tom went through the tunnel.  >>>  [start] tom fue al de de camino [end]
# 144 	: People do stupid things when they're tired.  >>>  [start] la gente hace cosas que están cansado [end]
# 145 	: I wouldn't want to do anything that would make Tom angry.  >>>  [start] no quiero hacer nada que tom [UNK] [end]
# 146 	: Are they here?  >>>  [start] están aquí [end]
# 147 	: I've heard that it's impossible to sound like a native speaker unless one starts speaking the language before the age of twelve.  >>>  [start] he oído que por que por más de un lugar como las [UNK] antes de [UNK] en una madre de
# 148 	: You're finished already.  >>>  [start] ya estás terminado [end]
# 149 	: Tom likes being alone.  >>>  [start] a tom le gusta estar sola [end]
# 150 	: Do you mind if I sit down?  >>>  [start] te importa si me siento la [UNK] [end]
# 151 	: I like you a lot.  >>>  [start] me [UNK] mucho [end]
# 152 	: I ate leftovers for lunch.  >>>  [start] me [UNK] el almuerzo [end]
# 153 	: The converse is also true.  >>>  [start] los [UNK] son muy verdad [end]
# 154 	: Tom doesn't know what to do anymore.  >>>  [start] tom ya no sabe qué hacer [end]
# 155 	: I'm having a hard time with French grammar.  >>>  [start] estoy de acuerdo en una vez en francés [UNK] [end]
# 156 	: Tom lacks experience.  >>>  [start] tom le falta experiencia [end]
# 157 	: I'm sure everything will work out just fine.  >>>  [start] estoy seguro de que va a llegar bien [end]
# 158 	: If you won a million yen, what would you do?  >>>  [start] si [UNK] un equipo de mil mil mil [UNK] [end]
# 159 	: He is a bit like his father.  >>>  [start] Él es un poco como en su padre [end]
# 160 	: I left my jacket in the classroom.  >>>  [start] me he ido la chaqueta la revista [end]
# 161 	: Tom refused to sign his name.  >>>  [start] tom se negó a [UNK] su nombre [end]
# 162 	: You're fired.  >>>  [start] estás [UNK] [end]
# 163 	: I don't follow.  >>>  [start] no me puedo mantener [end]
# 164 	: I easily found his office.  >>>  [start] me [UNK] con su oficina [end]
# 165 	: It's too dark.  >>>  [start] está demasiado oscuro [end]
# 166 	: I'm sleepy. I'm going to sleep. Good night.  >>>  [start] tengo sueño tengo que dormir anoche [end]
# 167 	: I don't want to walk home.  >>>  [start] no quiero salir a la casa [end]
# 168 	: She forced him to do it.  >>>  [start] ella lo ha [UNK] [end]
# 169 	: Who does Tom think he is anyway?  >>>  [start] quién piensa quién es de verdad [end]
# 170 	: Bunnies are so cute.  >>>  [start] qué en son tan [UNK] [end]
# 171 	: I have seen the picture before.  >>>  [start] he visto esa foto antes [end]
# 172 	: I saw him three years ago.  >>>  [start] lo vi tres años hace [end]
# 173 	: Please spare my life.  >>>  [start] por favor [UNK] mi vida [end]
# 174 	: Tom decided not to go to Boston.  >>>  [start] tom decidió que no ir a boston [end]
# 175 	: Tom is the defendant.  >>>  [start] tom es el de [UNK] [end]
# 176 	: You can't help Tom now.  >>>  [start] ahora no puedes ayudar a tom [end]
# 177 	: See you again.  >>>  [start] te veo de nuevo [end]
# 178 	: Look out for bees.  >>>  [start] mira por las [UNK] [end]
# 179 	: It would be fun to see how things change over the years.  >>>  [start] sería divertido hacer [end]
# 180 	: He has an inferiority complex.  >>>  [start] Él tiene [UNK] de [UNK] [end]
# 181 	: You can invite other people.  >>>  [start] puedes llamar a la gente [end]
# 182 	: Who helps your mother?  >>>  [start] quién ayuda a tu madre [end]
# 183 	: When you can't do what you want, you do what you can.  >>>  [start] cuándo tú puedes hacer lo que quieras que haga lo que sabes [end]
# 184 	: It wasn't my idea.  >>>  [start] no fue mi idea [end]
# 185 	: In my opinion, he is correct.  >>>  [start] en mi opinión él tiene razón [end]
# 186 	: I'll call them.  >>>  [start] la [UNK] [end]
# 187 	: I rang the bell six times.  >>>  [start] me he [UNK] la primera vez a las seis [end]
# 188 	: Please don't use French.  >>>  [start] no de usar el francés por favor [end]
# 189 	: My sister's going to kill me.  >>>  [start] mi hermana me va a matar [end]
# 190 	: All plants need water and light.  >>>  [start] todas las vacaciones [UNK] y luz y luz [end]
# 191 	: Tom licked his fingers.  >>>  [start] tom se [UNK] los ojos [end]
# 192 	: Will it bother you if I sit next to you?  >>>  [start] te [UNK] si te voy a pasar al lado [end]
# 193 	: He has a sharp tongue.  >>>  [start] Él tiene una lengua [UNK] [end]
# 194 	: Cloning people raises serious ethical problems.  >>>  [start] [UNK] personas un [UNK] [end]
# 195 	: Tom began to wonder who Mary had learned French from.  >>>  [start] tom se puso a [UNK] que mary había oído de tom [end]
# 196 	: An athlete must keep in good condition.  >>>  [start] un [UNK] debe pasar en la [end]
# 197 	: I love the food here.  >>>  [start] me encanta la comida aquí [end]
# 198 	: Hey, don't go.  >>>  [start] [UNK] no vete [end]
# 199 	: Tom often suffers from headaches.  >>>  [start] tom a menudo [UNK] en el [UNK] [end]
# 200 	: The ribbon doesn't match the dress.  >>>  [start] el se [UNK] no [UNK] el vestido [end]
# 201 	: You dropped your pencil.  >>>  [start] te [UNK] su lápiz [end]
# 202 	: Sorry, I couldn't help it.  >>>  [start] lamento no lo podría entender [end]
# 203 	: The police left without finding anything.  >>>  [start] la policía se fue sin encontrar sin nada [end]
# 204 	: A policeman came up to me.  >>>  [start] un policía me ha [UNK] [end]
# 205 	: Tom got angry when he saw Mary kissing John.  >>>  [start] tom se [UNK] cuando vio a mary su ver a john [end]
# 206 	: Where is Tom's house?  >>>  [start] dónde está la casa de tom [end]
# 207 	: Why is Tom so interested in that?  >>>  [start] por qué está tan bien tom [end]
# 208 	: I asked my father to buy this toy.  >>>  [start] le pedí a mi padre que me se lo haga este de a tom [end]
# 209 	: Could you speak more slowly, please?  >>>  [start] puedes hablar más despacio por favor [end]
# 210 	: I'm sure everything will work out just fine.  >>>  [start] estoy seguro de que va a llegar bien [end]
# 211 	: We did not help him, so he made it by himself.  >>>  [start] no lo le nosotros que lo fuera a hacerlo por mismo [end]
# 212 	: There's someone coming up the stairs.  >>>  [start] hay alguien dentro de la televisión [end]
# 213 	: The matter is all settled.  >>>  [start] el asunto es todo la parte de todo [end]
# 214 	: She married a bank clerk.  >>>  [start] ella se casó con un banco [UNK] una [UNK] [end]
# 215 	: Quantum physics is too difficult for a mere mortal to understand.  >>>  [start] los [UNK] de una [UNK] es muy difícil para de entender [end]
# 216 	: Can you deliver this?  >>>  [start] puedes [UNK] esto [end]
# 217 	: We couldn't figure out what they were trying to say.  >>>  [start] no podemos entender lo que estaban de decir [end]
# 218 	: I just want to say good luck.  >>>  [start] solo quiero decir una buena suerte [end]
# 219 	: What is the doctor doing?  >>>  [start] cuál es el médico [end]
# 220 	: We should not place too much emphasis on money.  >>>  [start] no debemos un lugar muy [UNK] con él demasiado [UNK] [end]
# 221 	: Lend me some money, if you have any.  >>>  [start] [UNK] algo de dinero si tienes algo [end]
# 222 	: They are always complaining.  >>>  [start] ellos siempre se están [UNK] [end]
# 223 	: I invited him over to my place.  >>>  [start] le lo le le pedí a mi casa [end]
# 224 	: Tom doesn't want to apologize.  >>>  [start] tom no quiere que te ayude [end]
# 225 	: Tom, say something.  >>>  [start] tom dice algo [end]
# 226 	: How early do I have to make a reservation to qualify for the discount?  >>>  [start] para qué tengo que hacer una [UNK] a la [end]
# 227 	: Can I work here?  >>>  [start] puedo trabajar aquí [end]
# 228 	: It is said that Friday the 13th is an unlucky day.  >>>  [start] se dice que el viernes por ser un día [UNK] en un día [end]
# 229 	: This is one of the best local newspapers.  >>>  [start] este es uno de los planes de la mejor [end]
# 230 	: I congratulated him on passing the entrance exam.  >>>  [start] lo [UNK] en la cena de [UNK] la [UNK] [end]
# 231 	: Why won't you talk to me, Tom?  >>>  [start] por qué no me [UNK] tom [end]
# 232 	: I think I can handle it.  >>>  [start] creo que puedo [UNK] [end]
# 233 	: I need a new car.  >>>  [start] necesito un auto nuevo [end]
# 234 	: The amount of paper produced by a country is closely related to its cultural standards.  >>>  [start] la [end]
# 235 	: I was late for the train.  >>>  [start] llegué tarde al tren [end]
# 236 	: A little girl caught her fingers in the door.  >>>  [start] una chica se de menudo se de la puerta con los ojos de la puerta [end]
# 237 	: Never tell a lie!  >>>  [start] no se lo [UNK] en ni la mentira [end]
# 238 	: She didn't reply.  >>>  [start] ella no ha [UNK] [end]
# 239 	: We love our customers.  >>>  [start] nos encanta nuestro de se [UNK] [end]
# 240 	: Tom didn't notice the look of disdain on Mary's face.  >>>  [start] tom no se dio cuenta de la cara de mary [UNK] [UNK] [end]
# 241 	: Everybody got sent back home.  >>>  [start] todos lo [UNK] en la casa [end]
# 242 	: The fence is painted green.  >>>  [start] la cerca de ella es [UNK] [end]
# 243 	: Most people don't like hospitals.  >>>  [start] la mayoría de las personas no les gustan los [UNK] [end]
# 244 	: They all looked happy.  >>>  [start] todos ellos se [UNK] bien [end]
# 245 	: Tom finally got hold of the rare stamp he wanted.  >>>  [start] tom al fin y la [UNK] de la [end]
# 246 	: He's going to love this.  >>>  [start] Él se va a enamorado de esto [end]
# 247 	: This sofa takes too much room.  >>>  [start] este ¡qué [UNK] demasiado pieza [end]
# 248 	: Tom's lunch includes a sandwich and an apple.  >>>  [start] el de almuerzo de tom un [UNK] un manzana y una el [UNK] [end]
# 249 	: I really want to go home now.  >>>  [start] ahora quiero ir a casa [end]
# 250 	: I know neither of his brothers.  >>>  [start] no sé nadie de su hermano [end]
# 251 	: Don't talk to me!  >>>  [start] tom no me lo [UNK] [end]
# 252 	: Tom appreciated Mary's support.  >>>  [start] tom a la [UNK] de mary [end]
# 253 	: Enjoy your youth while it lasts.  >>>  [start] el [UNK] ya lo [UNK] [end]
# 254 	: This coffee is so hot that I can't drink it.  >>>  [start] este café está muy tan caliente no puedo beber [end]
# 255 	: The author dedicated the book to his sister.  >>>  [start] el escritor [UNK] a su hermana [end]
# 256 	: I have to pick some flowers.  >>>  [start] tengo que llamar algunas flores [end]
# 257 	: This is not my car.  >>>  [start] este no es mi auto [end]
# 258 	: Mary is going to help us tomorrow.  >>>  [start] mary se va a ayudar mañana [end]
# 259 	: She cooks very well.  >>>  [start] ella se [UNK] muy bien [end]
# 260 	: He will be studying when you get up.  >>>  [start] Él estará estudiando cuando te [UNK] [end]
# 261 	: With winter coming on, the mountains will soon be covered with snow.  >>>  [start] al invierno se me pasa las la montaña pronto se [UNK] [end]
# 262 	: How are you today?  >>>  [start] cómo estás hoy [end]
# 263 	: What do you want to do in Boston?  >>>  [start] qué quieres hacer en boston [end]
# 264 	: I was attacked and robbed on my way home.  >>>  [start] me [UNK] y me [UNK] en la camino a casa [end]
# 265 	: Is it convenient for you if I come at 6 p.m.?  >>>  [start] te pasa bien si no voy a lo voy a la noche [end]
# 266 	: He made a great fortune in his lifetime.  >>>  [start] Él hizo una gran presidente en su camino [end]
# 267 	: I chuckled.  >>>  [start] yo [UNK] [end]
# 268 	: What are your intentions?  >>>  [start] sos sus [UNK] [end]
# 269 	: You're not old.  >>>  [start] no sos viejo [end]
# 270 	: I'd like to watch TV.  >>>  [start] quisiera ver la televisión [end]
# 271 	: I almost laughed out loud.  >>>  [start] casi me [UNK] de [UNK] [end]
# 272 	: Tom opened the freezer and got some ice for his drink.  >>>  [start] tom abrió el [UNK] y se de hielo para beber algo de hielo [end]
# 273 	: I like my chicken wings with barbeque sauce.  >>>  [start] me gusta mi escuela con [UNK] de se [UNK] con la se [UNK] [end]
# 274 	: The boy is clinging to his mother.  >>>  [start] el niño se le [UNK] a su madre [end]
# 275 	: I'm tired of watching television.  >>>  [start] estoy cansado de ver la televisión [end]
# 276 	: I anticipate that there will be problems on their expedition.  >>>  [start] [UNK] [UNK] que hay problemas en su de de se [UNK] en su de se [UNK] [end]
# 277 	: I locked myself in my room.  >>>  [start] me [UNK] con tom en mi habitación [end]
# 278 	: Tom changed everything.  >>>  [start] tom cambió todo [end]
# 279 	: Tom has put on some weight.  >>>  [start] tom ha [UNK] algo de peso [end]
# 280 	: The police are investigating the cause of the accident.  >>>  [start] la policía está [UNK] la razón del accidente [end]
# 281 	: Tom still lives with his mother.  >>>  [start] tom todavía vive con su madre [end]
# 282 	: The old couple had no children.  >>>  [start] la [UNK] tenía hijos un par de niños [end]
# 283 	: I told them nothing.  >>>  [start] no le dije nada [end]
# 284 	: The imposter was caught.  >>>  [start] los [UNK] fue [UNK] [end]
# 285 	: The garden is in front of the house.  >>>  [start] el jardín está en frente de la casa [end]
# 286 	: How much money do you want?  >>>  [start] cuánto dinero quieres [end]
# 287 	: Tom was my best friend when I was in high school.  >>>  [start] tom era mi mejor amigo cuando llegué en la escuela [end]
# 288 	: Tom is currently working on that problem.  >>>  [start] tom está de trabajando en ese problema [end]
# 289 	: He went abroad.  >>>  [start] se fue al extranjero [end]
# 290 	: I'm not crying.  >>>  [start] no estoy llorando [end]
# 291 	: Tom grinds his teeth in his sleep.  >>>  [start] tom se [UNK] los dientes en su sueño [end]
# 292 	: Has Tom told Mary?  >>>  [start] se lo ha dicho tom a mary [end]
# 293 	: You should know that.  >>>  [start] deberías saber eso [end]
# 294 	: It's to the point.  >>>  [start] es el punto de hacer eso [end]
# 295 	: She is writing a letter now.  >>>  [start] ahora ella está escribiendo una carta [end]
# 296 	: The French president is to visit Japan next month.  >>>  [start] el presidente de la presidente de japón viene el mes que viene [end]
# 297 	: Who has a better idea?  >>>  [start] quién tiene una idea mejor [end]
# 298 	: They should pay me.  >>>  [start] ellos me tienen que pagar [end]
# 299 	: I'm likely going to have a difficult time doing that.  >>>  [start] probablemente esta vez tengo mucho tiempo difícil [end]
# 300 	: I want an explanation.  >>>  [start] quiero una buena [end]
# 301 	: When did you begin learning German?  >>>  [start] cuándo [UNK] a aprender alemán [end]
# 302 	: This tea is too bitter.  >>>  [start] este té está demasiado libre [end]
# 303 	: Hey, look what I found.  >>>  [start] [UNK] lo que he encontrado [end]
# 304 	: I can't believe you're still hungry.  >>>  [start] no puedo creer que tienes hambre [end]
# 305 	: Are they brothers?  >>>  [start] son hermanos [end]
# 306 	: He has a deep affection for his son.  >>>  [start] tiene un [UNK] para su hijo [end]
# 307 	: I taught him how to swim.  >>>  [start] le le he dicho a nadar [end]
# 308 	: Long, long ago, there lived an old man in a village.  >>>  [start] hace mucho mucho de que había una gente en un pueblo en un pueblo [end]
# 309 	: I've already read this book.  >>>  [start] ya he leído este libro [end]
# 310 	: Tom has a hangover.  >>>  [start] tom tiene una se [UNK] [end]
# 311 	: Tom clearly doesn't want to be doing this.  >>>  [start] tom habla un buen [end]
# 312 	: Go first to those who you are sure will help you.  >>>  [start] vete a primero que estás a pensar que me vas a ayudar [end]
# 313 	: I like neither apples nor grapes.  >>>  [start] me gustan las manzanas ni siquiera sos [end]
# 314 	: Would you like to tell the next story?  >>>  [start] te gustaría decir la historia [end]
# 315 	: I share your idea.  >>>  [start] [UNK] con tu idea [end]
# 316 	: We have to figure it out.  >>>  [start] tenemos que de hacerlo [end]
# 317 	: He lives in Tokyo now.  >>>  [start] ahora vive en tokio [end]
# 318 	: We have homework.  >>>  [start] tenemos deberes [end]
# 319 	: No matter what happens, I will never change my mind.  >>>  [start] sin importar lo que pasa nunca me [UNK] la importa [end]
# 320 	: This team is trained by a good coach.  >>>  [start] este equipo está [UNK] por un buen buen de [UNK] [end]
# 321 	: Since it was getting even hotter, Tom peeled off another layer of clothing.  >>>  [start] como estaba [UNK] hasta más la vida tom [UNK] de otra vez que tom [end]
# 322 	: Tom plays the vibraphone exceptionally well.  >>>  [start] tom toca el [UNK] de [UNK] [end]
# 323 	: I've rented a room in Paris for a month.  >>>  [start] he [UNK] en una habitación al mes [end]
# 324 	: The bus is capable of carrying thirty people.  >>>  [start] en la autobús [UNK] en [UNK] personas [end]
# 325 	: Tom has lost control of the class.  >>>  [start] tom perdió la parte de la clase [end]
# 326 	: What time do you watch the news?  >>>  [start] a qué hora [UNK] la noticia [end]
# 327 	: I have to comb my hair.  >>>  [start] tengo que [UNK] el pelo [end]
# 328 	: Any of you can do it.  >>>  [start] cualquier cosa puedes hacerlo [end]
# 329 	: Are you seriously thinking about going?  >>>  [start] estás pensando en ir de lo que vamos a ir [end]
# 330 	: The company had to let many of its employees go.  >>>  [start] la compañía haber dejó que [UNK] de los [end]
# 331 	: I met Tom on my way to school.  >>>  [start] me encontré en la camino a tom en la escuela [end]
# 332 	: Tom and Mary have both done that.  >>>  [start] tom y mary tienen que hacerlo [end]
# 333 	: Are they satisfied?  >>>  [start] están satisfecho [end]
# 334 	: Thanks again for everything.  >>>  [start] gracias por todo [end]
# 335 	: I wonder why Tom didn't call me.  >>>  [start] me pregunto por qué tom no me ha encontrado [end]
# 336 	: My arm hurts.  >>>  [start] me da hielo mi brazo [end]
# 337 	: At least thirty students were absent.  >>>  [start] al menos tres años no tengo comida [end]
# 338 	: I want to be a magician.  >>>  [start] quiero ser un [UNK] [end]
# 339 	: He is still full of energy.  >>>  [start] Él todavía está lleno de a a a los a la no [end]
# 340 	: A lot of companies are going under lately because banks are so tight with their money.  >>>  [start] una [UNK] de las [UNK] están en lo correcta porque no están [UNK] de su dinero [end]
# 341 	: Tom has another plan.  >>>  [start] tom tiene otro plan [end]
# 342 	: You have been busy.  >>>  [start] has estado ocupado [end]
# 343 	: Tom still hasn't paid me.  >>>  [start] tom todavía no me ha dicho a mí mismo [end]
# 344 	: This was on the list.  >>>  [start] esta estaba en la lista [end]
# 345 	: None of us have eaten yet.  >>>  [start] nadie de nosotros ha comido ni [UNK] [end]
# 346 	: There's one more.  >>>  [start] hay una más [end]
# 347 	: Get your mother.  >>>  [start] [UNK] a tu madre [end]
# 348 	: Tom is one of Mary's neighbors.  >>>  [start] tom es uno de los trabajadores de tom [end]
# 349 	: Somebody is lying here.  >>>  [start] alguien está escribiendo alguien aquí [end]
# 350 	: Don't cheat.  >>>  [start] no [UNK] [end]
# 351 	: The company had to let many of its employees go.  >>>  [start] la compañía haber dejó que [UNK] de los [end]
# 352 	: Tom hasn't finished all his homework yet.  >>>  [start] tom ya no ha perdido su tarea todavía [end]
# 353 	: That is essential.  >>>  [start] eso es el [UNK] [end]
# 354 	: You seem so relaxed.  >>>  [start] pareces muy [UNK] [end]
# 355 	: Do you know how to use this?  >>>  [start] sabes cómo se ve esto [end]
# 356 	: I was unable to write down the number of the car.  >>>  [start] yo [UNK] que escribir el número de la última vez [end]
# 357 	: My computer doesn't work anymore.  >>>  [start] mi ordenador ya no trabaja [end]
# 358 	: You must have a driver's license before you can drive a car.  >>>  [start] debes tener una flor de el que [UNK] antes de que [UNK] un auto [end]
# 359 	: Tom ate everything on his plate.  >>>  [start] tom se comió todo el pelo [end]
# 360 	: Who is that man?  >>>  [start] quién es ese hombre [end]
# 361 	: Tom bent down to pick up something off the floor.  >>>  [start] tom se [UNK] a tomar algo de el piso [end]
# 362 	: Fire!  >>>  [start] se [UNK] el fuego [end]
# 363 	: I waited until the last minute.  >>>  [start] le le le le le le le le le le le le le le le le le le le le
# 364 	: You're all cowards.  >>>  [start] todos sos un de la [UNK] [end]
# 365 	: She came back an hour later.  >>>  [start] ella volvió una hora más tarde [end]
# 366 	: Tom is a good athlete.  >>>  [start] tom es un buen lugar [end]
# 367 	: I don't want your opinion.  >>>  [start] no quiero tu opinión [end]
# 368 	: Tom and Mary are both Christians.  >>>  [start] tom y mary son los a los a menudo [end]
# 369 	: I just needed a place to study.  >>>  [start] sólo necesito un lugar para estudiar [end]
# 370 	: Tom was interviewed on TV last night.  >>>  [start] tom estaba [UNK] en la televisión anoche [end]
# 371 	: Imagination affects every aspect of our lives.  >>>  [start] la madre [UNK] cada nuestra vida [end]
# 372 	: Do you have anything to eat in your pack?  >>>  [start] tienes algo que comer en tu [UNK] [end]
# 373 	: The rain lasted a week.  >>>  [start] la lluvia me ha [UNK] en una semana [end]
# 374 	: A bee flew out of the window.  >>>  [start] la un de de la ventana ha [UNK] [end]
# 375 	: Come to me.  >>>  [start] pasa a mí [end]
# 376 	: I'm sure you'll like it.  >>>  [start] estoy seguro de que te [UNK] [end]
# 377 	: You're the only person I know who has a sports car.  >>>  [start] sos la única persona que conozco que conozco a los [UNK] de un auto [end]
# 378 	: Do you know which room the meeting will be in?  >>>  [start] sabes qué habitación en la reunión [end]
# 379 	: Tom looked through the menu.  >>>  [start] tom miró el carta en el menú [end]
# 380 	: We saw nothing strange.  >>>  [start] no vimos nada extraño [end]
# 381 	: Last night, he studied all night long.  >>>  [start] anoche él [UNK] toda la noche [end]
# 382 	: Let me know if something's missing.  >>>  [start] [UNK] si algo está algo [end]
# 383 	: The time may come when people will have used up all the oil.  >>>  [start] hace la hora de que pasa cuándo la gente se ve por todo el de de su de ahí [end]
# 384 	: What do you think made him break his promise?  >>>  [start] qué crees que le [UNK] su promesa [end]
# 385 	: Tom is very famous.  >>>  [start] tom es muy canadiense [end]
# 386 	: He is a born poet.  >>>  [start] Él es un [UNK] [end]
# 387 	: I'll bear that in mind.  >>>  [start] me [UNK] en ese momento [end]
# 388 	: I don't want to fail my exams.  >>>  [start] no quiero [UNK] de mis a los de a los de la [end]
# 389 	: Running as fast as I could, I was able to catch up with my friend.  >>>  [start] a menudo tan rápido como yo podría hacer un juego [end]
# 390 	: Art is not a luxury, but a necessity.  >>>  [start] el amor no es un de [UNK] pero una a la [UNK] [end]
# 391 	: It was rather easy for them.  >>>  [start] fue muy fácil para ellos [end]
# 392 	: It's an easy way to make money.  >>>  [start] es una forma de hacer fácil [end]
# 393 	: The samurai decapitated his opponent in one fell swoop.  >>>  [start] los [UNK] [UNK] a su [UNK] en una [UNK] [end]
# 394 	: Tom seems really happy.  >>>  [start] tom parece muy feliz [end]
# 395 	: He made her feel like he wanted her to leave.  >>>  [start] Él hizo la bailar como que quería que fuera [end]
# 396 	: I think you had better stick to your present job.  >>>  [start] creo que te [UNK] el regalo para tu trabajo [end]
# 397 	: I have to fix the washing machine.  >>>  [start] tengo que hacer la foto [end]
# 398 	: When I opened the door of the refrigerator, an apple fell out.  >>>  [start] cuando sabe la puerta de la cara de la manzana se quedó en el suelo [end]
# 399 	: No woman is as arrogant as she is.  >>>  [start] la mujer es tan poco como la de la [UNK] [end]
# 400 	: Tom knows things.  >>>  [start] tom sabe cosas [end]
# 401 	: I'm going tomorrow.  >>>  [start] voy mañana [end]
# 402 	: I wrote a long letter to her.  >>>  [start] le le le le le le le le le le le le dije a ella [end]
# 403 	: Where is Paris?  >>>  [start] dónde está parís [end]
# 404 	: This is the biggest hotel in this city.  >>>  [start] este es el hotel más grande de la ciudad [end]
# 405 	: Look at those black clouds.  >>>  [start] mira estas [UNK] [UNK] de las [UNK] [end]
# 406 	: We had better leave her alone for a few minutes.  >>>  [start] hicimos ir antes de que la fuera a sola [end]
# 407 	: Why don't you tell Tom?  >>>  [start] por qué no le digas a tom [end]
# 408 	: You are very good at sewing.  >>>  [start] estás muy bien [UNK] [end]
# 409 	: She's good at tennis.  >>>  [start] ella es bueno para el tenis [end]
# 410 	: Are they here?  >>>  [start] están aquí [end]
# 411 	: I just wanted a coffee.  >>>  [start] sólo quería una café [end]
# 412 	: Tom thought the teacher had given him way too much homework to finish in one day.  >>>  [start] tom pensó que el profesor te había encontrado demasiado en terminar para el día en un día [end]
# 413 	: The wall is white on the inside and green on the outside.  >>>  [start] la pared es blanco y hacia la ciudad fuera hacia fuera fuera [end]
# 414 	: This vase is made of iron.  >>>  [start] esta [UNK] está [UNK] [end]
# 415 	: She is fond of animals.  >>>  [start] le cuesta animales [end]
# 416 	: Tom wanted to meet you.  >>>  [start] tom quería [UNK] [end]
# 417 	: My mother forgot to add salt to the salad.  >>>  [start] mi madre [UNK] de la sal de mi [UNK] [end]
# 418 	: We sat together in silence for some time.  >>>  [start] nos vimos oscuro en el rato [end]
# 419 	: The fender was badly dented.  >>>  [start] los [UNK] fue [UNK] [UNK] [end]
# 420 	: I have no funds in the bank.  >>>  [start] no tengo [UNK] en el banco [end]
# 421 	: I have a lot of photos.  >>>  [start] tengo muchas fotos [end]
# 422 	: You remember me, don't you?  >>>  [start] me te [UNK] de no es verdad [end]
# 423 	: You didn't answer me.  >>>  [start] no me [UNK] [end]
# 424 	: Tom and Mary are much stronger than we are.  >>>  [start] tom y mary son mucho más grande de lo que somos [end]
# 425 	: He realized his dream of becoming an artist.  >>>  [start] se dio cuenta de su sueño en un se [UNK] [end]
# 426 	: I am not older than he is.  >>>  [start] no soy mayor que él [end]
# 427 	: The older we become, the worse our memory gets.  >>>  [start] cuanto más alto [UNK] la película [end]
# 428 	: I am trying to learn English.  >>>  [start] estoy tratando de aprender inglés [end]
# 429 	: There are more than seven thousand languages in the world.  >>>  [start] hay una más de siete países en el mundo [end]
# 430 	: Tom told Mary that she was being childish.  >>>  [start] tom le dijo a mary que estaba [UNK] [end]
# 431 	: Let's open it.  >>>  [start] [UNK] [end]
# 432 	: This is why I fired him.  >>>  [start] por eso la razón por todo lo que me [UNK] [end]
# 433 	: He said hello to the woman.  >>>  [start] Él hizo una [UNK] a la mujer [end]
# 434 	: The new president did what he thought was right.  >>>  [start] el nuevo presidente sería el que él pensaba en lo que pensaba [end]
# 435 	: How long are you going to stay here?  >>>  [start] cuánto tiempo vas a pasar aquí [end]
# 436 	: One day he killed himself.  >>>  [start] un día se pidió a él [end]
# 437 	: We're baffled.  >>>  [start] estamos [UNK] [end]
# 438 	: It is not far away from the hotel.  >>>  [start] no está lejos de el hotel [end]
# 439 	: Come again any time.  >>>  [start] pasa una vez de nuevo [end]
# 440 	: Good afternoon.  >>>  [start] la tarde mismo al mismo [end]
# 441 	: She is likely to come.  >>>  [start] probablemente ella estará [end]
# 442 	: He used every chance to practice English.  >>>  [start] Él solía toda la oportunidad de inglés [end]
# 443 	: I've always wanted to meet you.  >>>  [start] siempre he tenido que te vi en ti [end]
# 444 	: Did you get the flowers that I sent you?  >>>  [start] [UNK] las flores que te he dicho [end]
# 445 	: It took less than five minutes.  >>>  [start] tomó menos de cinco minutos [end]
# 446 	: Who's taking responsibility for this?  >>>  [start] quién se [UNK] por esto [end]
# 447 	: You shouldn't read a book in a room this dim.  >>>  [start] no deberías leer un libro en una habitación así de un de [UNK] [end]
# 448 	: Give me a hundred dollars.  >>>  [start] dame cien dólares [end]
# 449 	: How many boys are in this class?  >>>  [start] cuántos niños hay en esta clase [end]
# 450 	: I'm sorry.  >>>  [start] lo siento [end]
# 451 	: Maybe we could get together sometime and have lunch.  >>>  [start] tal vez podría pasar usted más de [UNK] a la cena [end]
# 452 	: Mary wants to become a vet because she loves animals.  >>>  [start] mary quiere ser [UNK] en porque tom la leche [end]
# 453 	: They aren't there.  >>>  [start] no hay ahí [end]
# 454 	: How many Christmas presents did you give this year?  >>>  [start] cuántos regalos te has [UNK] este año [end]
# 455 	: My shopping bag broke.  >>>  [start] mi [UNK] de [UNK] [end]
# 456 	: She returned from a trip.  >>>  [start] ella volvió de un viaje [end]
# 457 	: This is by far the most interesting of all his novels.  >>>  [start] esta es de lejos la interesante más interesante de todas las diez personas [end]
# 458 	: A little bird told me.  >>>  [start] un poco me dio un poco de pájaro [end]
# 459 	: I saw a boy knocked down by a car.  >>>  [start] vi a un niño [UNK] en un auto [end]
# 460 	: This is the only camera I've got.  >>>  [start] esta es la única cámara de la única que tengo la única última cámara [end]
# 461 	: You'd better hold your tongue.  >>>  [start] mejor [UNK] tu lengua [end]
# 462 	: You can see many animals in this forest.  >>>  [start] puedes ver muchos animales en este bosque [end]
# 463 	: Although he is young, he is very careful.  >>>  [start] aunque él es joven es muy cuidado [end]
# 464 	: You should learn how to use your dictionary.  >>>  [start] deberías aprender a usar el diccionario [end]
# 465 	: This is mahjong.  >>>  [start] esto es un [UNK] [end]
# 466 	: It looked so delicious.  >>>  [start] parecía muy muy [UNK] [end]
# 467 	: Have faith.  >>>  [start] [UNK] [end]
# 468 	: He hates carrots.  >>>  [start] Él toca las vacaciones de [UNK] [end]
# 469 	: What language do they speak in the United States?  >>>  [start] qué lengua se habla en los estados unidos [end]
# 470 	: Would the two of you quit bickering?  >>>  [start] [UNK] a mis dos [UNK] [end]
# 471 	: We are accustomed to wearing shoes.  >>>  [start] estamos acostumbrado a tomar zapatos [end]
# 472 	: Are they going to employ more people?  >>>  [start] ellos van a [UNK] más personas [end]
# 473 	: Does your throat hurt?  >>>  [start] la camisa tiene la cabeza [end]
# 474 	: He is afraid of death.  >>>  [start] Él le tiene miedo a la muerte [end]
# 475 	: I want to ask you something, Ms. Ionescu.  >>>  [start] quiero hacerte una lista que [UNK] [UNK] [end]
# 476 	: Tom's son's name is John.  >>>  [start] el nombre de el nombre de el hijo de tom es john [end]
# 477 	: I wrote a letter in French.  >>>  [start] yo le he dicho una carta en francés [end]
# 478 	: I'm not as talkative as you.  >>>  [start] no soy tan [UNK] como tú [end]
# 479 	: I lost everything I had.  >>>  [start] he perdido todo lo que había tenido [end]
# 480 	: Tom dated Mary when they were both teenagers.  >>>  [start] tom [UNK] a mary cuando tenía los animales [end]
# 481 	: Tom was lucky that he didn't lose his job.  >>>  [start] tom fue muy malo que no [UNK] su trabajo [end]
# 482 	: How does he know that?  >>>  [start] cómo sabe qué [end]
# 483 	: I framed Tom.  >>>  [start] [UNK] a tom [end]
# 484 	: You must take this medicine, whether you like it or not.  >>>  [start] debes tomar esta medicina te [UNK] verdad o no [end]
# 485 	: Tom is alone in the kitchen.  >>>  [start] tom está sola en la cocina [end]
# 486 	: The auto was in the middle of the road.  >>>  [start] la [UNK] estaba en medio de la calle [end]
# 487 	: These small letters can only be read with a magnifying glass.  >>>  [start] estos cartas pueden pasar solo el concierto con un vaso de agua [end]
# 488 	: I'll have them repair my car.  >>>  [start] se me lo voy a comprar mi auto [end]
# 489 	: You need to hurry.  >>>  [start] debes [UNK] [end]
# 490 	: I'll ask Tom to meet you tomorrow at three o'clock.  >>>  [start] le voy a pasar a tom a la hora de salir a las tres [end]
# 491 	: The haze enveloped London.  >>>  [start] la [UNK] londres a las a las a londres [end]
# 492 	: Which house do they live in?  >>>  [start] en qué casa viven ellos [end]
# 493 	: He has a dog.  >>>  [start] Él tiene un perro [end]
# 494 	: His bark is worse than his bite.  >>>  [start] su lista la luz que se [UNK] [end]
# 495 	: I didn't think of that.  >>>  [start] no pensaba en eso [end]
# 496 	: He tried writing a short story.  >>>  [start] Él trató de escribir una historia [end]
# 497 	: He likes playing football.  >>>  [start] a él le gusta jugar al fútbol [end]
# 498 	: He came running.  >>>  [start] Él vino hacia correr [end]
# 499 	: We're in agreement.  >>>  [start] estamos en acuerdo [end]
# 500 	: What I remember most about that movie is the last scene.  >>>  [start] lo que me acuerdo de la película es la última parte de esa película [end]
# 501 	: I enjoyed the concert except that the hall was cold.  >>>  [start] me [UNK] el concierto pero no [UNK] de la habitación estaba frío [end]
# 502 	: Young men and women fought to defend their country.  >>>  [start] los hombres y las mujeres [UNK] a su país [end]
# 503 	: You don't have to do what Tom says.  >>>  [start] no tienes que hacer lo que tom dice [end]
# 504 	: I feel your pain.  >>>  [start] siento tu dolor [end]
# 505 	: My friend is studying Korean.  >>>  [start] mi amigo está estudiando por la lengua [end]
# 506 	: Don't worry so much.  >>>  [start] no te olvides tanto [end]
# 507 	: The man attacked her with the intention of killing her.  >>>  [start] el hombre la [UNK] de la foto de la mujer [end]
# 508 	: Which is your guitar?  >>>  [start] cuál es tu guitarra [end]
# 509 	: Tom seems to believe everything Mary says.  >>>  [start] tom parece que todo lo que sabe [end]
# 510 	: It's about time I was going home.  >>>  [start] está a hora de que me voy a la casa [end]
# 511 	: It's me.  >>>  [start] yo es yo [end]
# 512 	: Did you watch this movie?  >>>  [start] viste esta película [end]
# 513 	: Tom invited Mary to dinner.  >>>  [start] tom pidió a mary que la cena [end]
# 514 	: Tom has wavy brown hair and blue eyes.  >>>  [start] tom tiene pelo [UNK] el pelo o mary [end]
# 515 	: I wonder if it really was a coincidence.  >>>  [start] me pregunto si de cuándo se [UNK] una se [UNK] [end]
# 516 	: Tom is a very able teacher.  >>>  [start] tom es una persona muy de profesor [end]
# 517 	: Look at this picture.  >>>  [start] mira esta foto [end]
# 518 	: What kinds of things do you have on the computer?  >>>  [start] qué clase de cosas tienes en la ordenador [end]
# 519 	: I don't know what the consequences will be.  >>>  [start] no sé qué se [UNK] [end]
# 520 	: They always complain.  >>>  [start] ellos se [UNK] [end]
# 521 	: Isn't that true?  >>>  [start] no es eso verdad [end]
# 522 	: It used to be thought that the earth was flat.  >>>  [start] solía ser [UNK] de la tierra en la tierra [end]
# 523 	: You're tired, aren't you? Why don't you get to bed?  >>>  [start] estás cansado que no te [UNK] en la cama [end]
# 524 	: That boy is really shy.  >>>  [start] ese niño es muy tímido [end]
# 525 	: I'll go get the pizza.  >>>  [start] voy a hacer la ley [end]
# 526 	: I want to see my brother.  >>>  [start] quiero ver a mi hermano [end]
# 527 	: Help me move this stone.  >>>  [start] ayuda a esta piedra [end]
# 528 	: He looked much better this morning than yesterday.  >>>  [start] anoche parecía bien tu hermano ayer [end]
# ...
# 821 	: Tom's cat had nine kittens.  >>>  [start] el gato tom se [UNK] a las nueve [end]
# 822 	: They haven't found Tom.  >>>  [start] no han encontrado a tom [end]
# 823 	: Go brush your teeth.  >>>  [start] vete a los dientes [end]
# 824 	: I lost my notebook today.  >>>  [start] hoy he perdido mi día [end]
# 825 	: Tom went back to his hometown.  >>>  [start] tom ha [UNK] a su ciudad de [UNK] [end]
# 826 	: Am I on the right road?  >>>  [start] estoy en la razón [end]
# 827 	: Tom wrote Mary a letter.  >>>  [start] tom le prometió a mary una carta [end]
# 828 	: The boy doesn't know how to behave.  >>>  [start] el niño no sabe cómo se [UNK] [end]
# 829 	: I have never fed my dog a banana.  >>>  [start] nunca he [UNK] a mi perro a [UNK] [end]
# 830 	: I like butter better than cheese.  >>>  [start] me gusta más el dinero que el queso [end]
# 831 	: I broke my leg.  >>>  [start] me [UNK] la pierna [end]
# 832 	: Our team won.  >>>  [start] nuestro equipo ganó nuestro [end]
# 833 	: I'd like to say a few words.  >>>  [start] quisiera decir una palabras [end]
# 834 	: What was your hobby when you were a teenager?  >>>  [start] cuál fue tu pasatiempo cuando sería un no un no un de [UNK] [end]
# 835 	: Tom agreed.  >>>  [start] tom [UNK] [end]
# 836 	: The doors on the left side will open.  >>>  [start] las [UNK] de que se [UNK] el lado [end]
# 837 	: What's your favorite place to go when you want to think?  >>>  [start] cuál es tu lugar favorita para ir cuando quieres [end]
# 838 	: Tom didn't say anything.  >>>  [start] tom no dijo nada [end]
# 839 	: He gets up at 7.  >>>  [start] Él se lleva a las 230 [end]
# 840 	: What are you not telling me?  >>>  [start] qué no me estás diciendo [end]
# 841 	: What will they do?  >>>  [start] qué haría ellos [end]
# 842 	: He handed me the letter and left.  >>>  [start] me dio la carta de la carta y se fue [end]
# 843 	: Hello, it's me. Could you come pick me up at the station?  >>>  [start] [UNK] es lo que podría llegar a la estación [end]
# 844 	: I'm fair.  >>>  [start] soy a la razón [end]
# 845 	: I decided that I wouldn't do that.  >>>  [start] he decidido que no lo haría [end]
# 846 	: Did you see how big their house is?  >>>  [start] viste como en su casa [end]
# 847 	: Tom may have been sleeping at the time.  >>>  [start] tom puede haber estado durmiendo en el momento [end]
# 848 	: The wall is freshly painted.  >>>  [start] la pared está [UNK] de [UNK] [end]
# 849 	: Please give me a glass of water.  >>>  [start] dame un vaso de agua por favor [end]
# 850 	: They'll never understand.  >>>  [start] nunca lo [UNK] [end]
# 851 	: They're about to leave.  >>>  [start] son punto de que se [UNK] [end]
# 852 	: Would you rather visit Boston or Chicago?  >>>  [start] sería a pescar boston o a la semana [end]
# 853 	: Tom says you're good at tennis.  >>>  [start] tom dice que sos el tenis [end]
# 854 	: Tom ignored Mary's advice.  >>>  [start] tom no no no no se puso el consejo de mary [end]
# 855 	: Tom lives with his family.  >>>  [start] tom vive con su familia [end]
# 856 	: Do you have a budget?  >>>  [start] tienes un de a [end]
# 857 	: I can fix this.  >>>  [start] yo puedo hacer esto [end]
# 858 	: My uncle died of cancer two years ago.  >>>  [start] mi tío murió de piano hace dos años [end]
# 859 	: Try to be patient with others.  >>>  [start] [UNK] tener paciencia con otros [end]
# 860 	: I haven't seen her since last month.  >>>  [start] no lo he visto desde hace un mes [end]
# 861 	: It needs new batteries.  >>>  [start] necesita nuevo a no [UNK] [end]
# 862 	: Did you make it?  >>>  [start] lo hizo [end]
# 863 	: Tom hardly ever listens to the radio.  >>>  [start] tom casi no llama a la radio [end]
# 864 	: She took him to the lake.  >>>  [start] ella le tomó al lago [end]
# 865 	: Don't try to blame this all on me.  >>>  [start] no lo olvides de que [UNK] por mí [end]
# 866 	: You'll regret this in the morning.  >>>  [start] te [UNK] esto en la mañana [end]
# 867 	: I got up at six this morning.  >>>  [start] me he [UNK] a las seis esta mañana [end]
# 868 	: I go to school at seven o'clock.  >>>  [start] voy a la escuela a las siete [end]
# 869 	: You are as tall as my sister.  >>>  [start] sos tan alto como mi hermana [end]
# 870 	: Tom was sad and lonely.  >>>  [start] tom estaba triste y solo [end]
# 871 	: May I call around 2:30?  >>>  [start] puedo llamar a las 230 [end]
# 872 	: I'm not a doctor, but a teacher.  >>>  [start] no soy médico pero es profesor [end]
# 873 	: Nothing can stop them.  >>>  [start] nada puede dejar de los que [UNK] [end]
# 874 	: I've decided to marry Tom.  >>>  [start] he decidido de [UNK] a tom [end]
# 875 	: Now, don't be late.  >>>  [start] ahora no va a llegar tarde [end]
# 876 	: It was a violent crime.  >>>  [start] fue un crimen por un crimen a me [UNK] [end]
# 877 	: We've already done our work.  >>>  [start] ya hemos hecho nuestro trabajo [end]
# 878 	: It's good to see you.  >>>  [start] es bueno verte [end]
# 879 	: Young men and women fought to defend their country.  >>>  [start] los hombres y las mujeres [UNK] a su país [end]
# 880 	: I'm single again.  >>>  [start] estoy [UNK] de nuevo [end]
# 881 	: It is too difficult a problem for me to solve.  >>>  [start] es demasiado difícil para un problema para que él me [UNK] [end]
# 882 	: I can finally tell you about what I did during the war.  >>>  [start] podría decir la razón por lo que hice en la guerra [end]
# 883 	: Tom took off his shoes and socks.  >>>  [start] tom se sacó los zapatos y los [UNK] [end]
# 884 	: How old is your uncle?  >>>  [start] qué edad tiene tu tío [end]
# 885 	: Tom may be right.  >>>  [start] tom puede ser el mismo [end]
# 886 	: Tom needs to know the truth.  >>>  [start] tom necesita saber la verdad [end]
# 887 	: Answer me, please.  >>>  [start] [UNK] por favor [end]
# 888 	: Tom looked very happy.  >>>  [start] tom se veía muy feliz [end]
# 889 	: I'm sure I have the right number.  >>>  [start] estoy seguro de que tengo el número de teléfono en la última vez [end]
# 890 	: I think we're out of danger.  >>>  [start] creo que fuera de peligro [end]
# 891 	: No one asked you.  >>>  [start] nadie te preguntó nadie [end]
# 892 	: I had no doubts.  >>>  [start] no tenía ni sentido [end]
# 893 	: What do you think they want?  >>>  [start] qué crees que ellos quieras [end]
# 894 	: Tom's well.  >>>  [start] tom está bien [end]
# 895 	: The delay forced us to stay overnight in an expensive hotel.  >>>  [start] los [UNK] nos a la noche [UNK] que [UNK] en un hotel [UNK] [end]
# 896 	: It's not an easy question.  >>>  [start] no es una pregunta fácil [end]
# 897 	: The USA dropped an atomic bomb on Hiroshima in 1945.  >>>  [start] los estados unidos [UNK] una bomba en se [UNK] en se [UNK] [end]
# 898 	: Sometimes a cigar is just a cigar.  >>>  [start] a veces un de [UNK] es un de [UNK] [end]
# 899 	: He produced a rabbit out of his hat by magic.  >>>  [start] Él [UNK] un un [UNK] de su sombrero por la [end]
# 900 	: When were you born?  >>>  [start] cuándo [UNK] [end]
# 901 	: Don't ask me why.  >>>  [start] no me lo haga por qué [end]
# 902 	: I need some good advice.  >>>  [start] necesito algo de buen dinero [end]
# 903 	: Don't back up. There's a tree behind you.  >>>  [start] no se me [UNK] el árbol entre vos [end]
# 904 	: They didn't do it.  >>>  [start] no lo hizo [end]
# 905 	: She enjoyed herself very much at the party yesterday.  >>>  [start] ella se de bien que se [UNK] en la fiesta ayer [end]
# 906 	: I know you have a girlfriend.  >>>  [start] sé que tienen novia [end]
# 907 	: It is hard to wake up without a strong cup of coffee.  >>>  [start] se puede tomar la un [UNK] sin una oportunidad [end]
# 908 	: I stopped at the supermarket on my way home.  >>>  [start] me he dejado de la camino a casa en la camino [end]
# 909 	: She told me that she loved me.  >>>  [start] me dijo que me quería [end]
# 910 	: I do remember the day very well.  >>>  [start] me acuerdo muy bien el día [end]
# 911 	: She must have forgotten the promise.  >>>  [start] debe haber olvidado la promesa [end]
# 912 	: He's swimming now.  >>>  [start] Él está a nadar ahora [end]
# 913 	: Find out how Tom plans to spend his weekend.  >>>  [start] [UNK] cómo se [UNK] tom para pasar el fin de semana [end]
# 914 	: I assume you're referring to what happened here recently.  >>>  [start] supongo que te [UNK] hasta que aquí pasa [end]
# 915 	: Tom was badly injured in a traffic accident.  >>>  [start] tom ha [UNK] un accidente en un accidente de picnic [end]
# 916 	: Please turn off the radio and turn on the TV.  >>>  [start] por favor [UNK] la radio y [UNK] la televisión [end]
# 917 	: Can you frame this picture for me?  >>>  [start] me puede [UNK] este cuadro para mí [end]
# 918 	: Can you lift this stone?  >>>  [start] puedes [UNK] esta piedra [end]
# 919 	: She remarried when she was in her mid-forties.  >>>  [start] ella se [UNK] cuando estaba en su [UNK] [end]
# 920 	: He's an agent for a big insurance company.  >>>  [start] Él es un [UNK] para una gran compañía [end]
# 921 	: Tom tried to make both ends meet.  >>>  [start] tom trató de hacer que los [UNK] a ver [end]
# 922 	: I've done worse.  >>>  [start] lo he hecho peor [end]
# 923 	: She screamed when she saw the snake.  >>>  [start] ella en la la educación que vio la educación [end]
# 924 	: It is no exaggeration to call him a genius.  >>>  [start] no es [UNK] [UNK] como un equipo de la [UNK] [end]
# 925 	: Don't call her now.  >>>  [start] no la canción ahora [end]
# 926 	: My grandmother lives by herself.  >>>  [start] mi abuela vive en la vida sola [end]
# 927 	: Tom has a bad reputation.  >>>  [start] tom tiene una mala educación [end]
# 928 	: You should ask Mary out on a date.  >>>  [start] deberías hacerte una cena en una lugar [end]
# 929 	: His girlfriend is Japanese.  >>>  [start] su novia es inglés [end]
# 930 	: Creationism is a pseudo-science.  >>>  [start] [UNK] es un [UNK] [end]
# 931 	: He regretted not having taken my advice.  >>>  [start] parece que él no me [UNK] a mi consejo [end]
# 932 	: He gave her a book.  >>>  [start] le dio un libro a tom [end]
# 933 	: Tom just shot Mary.  >>>  [start] tom solo le ha [UNK] a mary [end]
# 934 	: I forgot to pay the rent.  >>>  [start] he ido a pagar la [UNK] del se me [UNK] [end]
# 935 	: Tom leaned back on the couch.  >>>  [start] tom se [UNK] en el [end]
# 936 	: What do your friends call you?  >>>  [start] cómo te [UNK] tus amigos [end]
# 937 	: We ran around the park.  >>>  [start] [UNK] hacia el parque [end]
# 938 	: This is a mechanical toy.  >>>  [start] este es un te [UNK] de a la [UNK] de me parece [end]
# 939 	: The official in charge let me in.  >>>  [start] las [UNK] me [UNK] a mí mismo [end]
# 940 	: If you watch the sun setting on a warm, damp day, you can see the moisture changing the shape of the sun.  >>>  [start] si [UNK] la luz se [UNK] en la luz temprano puede hacer [UNK] en la [UNK] de la llegar las
# 941 	: Tom doesn't want to be a hero.  >>>  [start] tom no quiere ser un héroe [end]
# 942 	: No one likes war.  >>>  [start] a nadie le gustan la guerra a nadie [end]
# 943 	: Someday you should give it a try.  >>>  [start] algún día deberías [UNK] [end]
# 944 	: May I sit next to you?  >>>  [start] puedo [UNK] a tu lado [end]
# 945 	: Tom came.  >>>  [start] tom vino [end]
# 946 	: I said shut up!  >>>  [start] dije la corazón [UNK] [end]
# 947 	: Tom is having a panic attack.  >>>  [start] tom está de estar en un [UNK] [UNK] [end]
# 948 	: Tom is too lazy to cook.  >>>  [start] tom es demasiado [UNK] como para cocinar [end]
# 949 	: This room is cold.  >>>  [start] esta habitación está frío [end]
# 950 	: We're not so young that we don't understand what love is.  >>>  [start] no somos muy joven para que no lo sabemos el amor [end]
# 951 	: Tom continued to honk the horn.  >>>  [start] tom hizo que [UNK] la maría [end]
# 952 	: In terms of the pay you will get, is this a good job?  >>>  [start] en la tierra se [UNK] que te [UNK] es un buen trabajo [end]
# 953 	: That's enough money to cover the expenses.  >>>  [start] eso es dinero para que [UNK] los [UNK] [end]
# 954 	: Thanks for this.  >>>  [start] gracias por esto [end]
# 955 	: She is trying to save as much money as she can.  >>>  [start] ella está tratando de hacer tanto dinero como pudo [end]
# 956 	: She wished to be beautiful.  >>>  [start] ella toma un linda linda [end]
# 957 	: There is a key on the desk.  >>>  [start] hay una llave sobre el escritorio [end]
# 958 	: What Tom did was incredibly stupid.  >>>  [start] lo que tom hizo fue una estúpido [end]
# 959 	: You promised not to do that anymore.  >>>  [start] ya no necesitas hacerlo [end]
# 960 	: Mary baked three dozen cookies for Tom's party.  >>>  [start] mary [UNK] tres [UNK] para la fiesta de tom [end]
# 961 	: Tom sharpened a pencil.  >>>  [start] tom [UNK] un lápiz [end]
# 962 	: When I got the phone call telling me of my father's death, I was completely flustered.  >>>  [start] cuando tenía la llamada me llamar a mi padre de padre la muerte de la muerte me [UNK] [end]
# 963 	: He has a black shirt.  >>>  [start] tiene una camisa negro [end]
# 964 	: This glass contains water.  >>>  [start] este [UNK] agua [end]
# 965 	: She lives quite close by.  >>>  [start] ella vive bastante cerca de ella [end]
# 966 	: The cat ran after the rat.  >>>  [start] el gato dejó hacia la la la la se [UNK] [end]
# 967 	: That hotel is very near the lake.  >>>  [start] ese hotel está muy cerca de el lago [end]
# 968 	: He seldom, if ever, goes to church.  >>>  [start] Él ni vez un va a la iglesia [end]
# 969 	: I'm not going if Tom goes.  >>>  [start] no voy a ir a tomás [end]
# 970 	: What did I do?  >>>  [start] qué hice [end]
# 971 	: Did they come today?  >>>  [start] ha estado a la [UNK] hoy [end]
# 972 	: Get rid of the gun.  >>>  [start] [UNK] de esta arma [end]
# 973 	: You made me lose my mind.  >>>  [start] me [UNK] la cabeza [end]
# 974 	: You can see it now.  >>>  [start] ahora puedes lo puedes como lo puedes [end]
# 975 	: Start running.  >>>  [start] pasa a correr [end]
# 976 	: The judge fined him five dollars.  >>>  [start] la [UNK] le [UNK] cinco dólares [end]
# 977 	: He cried for joy.  >>>  [start] Él no no no no ha [UNK] por la [UNK] [end]
# 978 	: Tom also needs to fill out this form.  >>>  [start] tom también necesita este descanso [end]
# 979 	: Please find out where he is.  >>>  [start] por favor [UNK] [end]
# 980 	: I hope that you are good.  >>>  [start] espero que los [UNK] sos buena [end]
# 981 	: You have to answer all of these questions.  >>>  [start] tienes que responder todas estas preguntas [end]
# 982 	: Tom saw the video.  >>>  [start] tom vio el va a me a me a un se [UNK] [end]
# 983 	: Tom asked Mary to sing louder.  >>>  [start] tom le pidió a mary que [UNK] más [end]
# 984 	: I'm not tall.  >>>  [start] no soy alto [end]
# 985 	: Suddenly it began to rain.  >>>  [start] de repente se puso a llover [end]
# 986 	: Nothing will happen until 2:30.  >>>  [start] nada pasa a punto hasta las 230 [end]
# 987 	: You ought not to miss it.  >>>  [start] no te debes [UNK] [end]
# 988 	: Please keep the fire from going out.  >>>  [start] por favor [UNK] el fuego a salir a salir [end]
# 989 	: You can't sit with me.  >>>  [start] no puedes [UNK] conmigo [end]
# 990 	: Tom finally figured out what he'd been doing wrong.  >>>  [start] tom al fin él estaba enfermo [end]
# 991 	: She asked me if she could use the phone.  >>>  [start] ella me preguntó si pudo usar el teléfono [end]
# 992 	: I should've gone with you.  >>>  [start] debería haber ido contigo [end]
# 993 	: People need to enjoy themselves.  >>>  [start] la gente necesita [UNK] para ellos [end]
# 994 	: Good results are expected.  >>>  [start] los [UNK] tienen muchos amigos [UNK] [end]
# 995 	: Tom said Mary's comments were misleading.  >>>  [start] tom dijo que los que tom eran [UNK] [end]
# 996 	: The boy I love doesn't love me.  >>>  [start] el niño me amo a tom [end]
# 997 	: Tom will provide music.  >>>  [start] tom [UNK] la música [end]
# 998 	: We won't surrender.  >>>  [start] no te [UNK] [end]
# 999 	: Tom can't wait to get started.  >>>  [start] tom no puede esperar [end]
# predict finish :  2022-09-19 09:01:40.851096

# %%
# !nvidia-smi
# Out:
# Mon Sep 19 09:01:40 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   74C    P0    30W /  70W |   1644MiB / 15109MiB |      5%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
